# %% [raw]
# ---
# format:
#   html:
#     embed-resources: true
# ---

# %% [markdown]
# # Median of 2 sorted lists

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
from pydantic import BaseModel
import numpy as np
import pandas as pd

# %% [markdown]
# ### Utils

# %%
def pad(x):
    return [-float("inf")] + x + [float("inf")]

class Pointers():
    def __init__(self, high, target, low):
        self.high = high
        self.target = target
        self.low = low

class BorderValues():
    def __init__(self, max_low, min_high):
        self.max_low = max_low
        self.min_high = min_high

class OrderedList:
    def __init__(self, nums, target=None):
        self.list = nums
        self.padded_list = pad(nums)
        self.n = len(self.padded_list)
        self.search_idx = Pointers(low=0, target=self.n // 2, high=self.n)
        # override target if given
        if target != None:
            self.set_target(target)
        else:
            self.set_border_values()

    def set_target(self, target):
        self.search_idx.target = target
        self.set_border_values()
        
    def set_border_values(self):
        self.split = BorderValues(
            max_low=self.padded_list[self.search_idx.target - 1], 
            min_high=self.padded_list[self.search_idx.target],
        )
        
    def next_target(self, up=True):
        if up:
            self.search_idx.low = self.search_idx.target
        else:
            self.search_idx.high = self.search_idx.target
        self.search_idx.target = (self.search_idx.low + self.search_idx.high) // 2
        self.set_border_values()

    def __repr__(self):
        return str(self.list)
        
def find_median(a, b, target_index):
    a_lower_lte_b_upper = a.split.max_low <= b.split.min_high
    b_lower_lte_a_upper = b.split.max_low <= a.split.min_high
    
    if not a_lower_lte_b_upper:
        a.next_target(up=False)
        b.search_idx.target = target_index - a.search_idx.target
        b.set_border_values()
        a, b = find_median(a, b, target_index)
    elif not b_lower_lte_a_upper:
        a.next_target(up=True)
        b.search_idx.target = target_index - a.search_idx.target
        b.set_border_values()
        a, b = find_median(a, b, target_index)
        
    return a, b
    
def calculate_median(a, b):
    n = a.n + b.n
    max_low = max(a.split.max_low, b.split.max_low)
    min_high = min(a.split.min_high, b.split.min_high)
    #print(median_input_values)
    if n % 2 == 0:
        med = (max_low + min_high) / 2.0
    else:
        med = min_high
        
    return med
    
def main(nums1, nums2):
    a, b = OrderedList(nums1), OrderedList(nums2)
    # make sure a contains the shorter list
    a, b = (a, b) if a.n <= b.n else (b, a)
    target_index = (a.n + b.n) // 2
    b.set_target(target_index - a.search_idx.target)
    a, b = find_median(a, b, target_index)
    med = calculate_median(a, b)
    return a, b, med

# %%
def highlight_ol(ol: OrderedList):
    green_cols = list(range(ol.search_idx.low, ol.search_idx.target))
    blue_cols = list(range(ol.search_idx.target, ol.search_idx.high))
    s = (
        pd.Series(ol.padded_list).to_frame().T
        .style
        .set_properties(subset=green_cols, **{"background-color": "lightgreen"})
        .set_properties(subset=blue_cols, **{"background-color": "lightblue"})
    )
    return s

# %%
override_a = False
override_b = False

na_ = np.random.randint(1, 100)
nb_ = np.random.randint(1, 100)

a_ = np.random.randint(0, 60, na_).tolist()
a_.sort()

# override a
#override_a = True
if override_a:
    a_ = [1]
    na_ = len(a_)

b_ = np.random.randint(40, 100, nb_).tolist()
b_.sort()

# override b
#override_b = True
if override_b:
    b_ = [1]
    nb_ = len(b_)

c_ = np.concat([a_, b_]).astype(int).tolist()
c_.sort()
n_ = len(c_)
med_calc = np.median(c_)

display(highlight_ol(OrderedList(c_)))
print(f"calculated median = {med_calc}")
# Out:
# <style type="text/css">
# #T_1f384_row0_col0, #T_1f384_row0_col1, #T_1f384_row0_col2, #T_1f384_row0_col3, #T_1f384_row0_col4, #T_1f384_row0_col5, #T_1f384_row0_col6, #T_1f384_row0_col7, #T_1f384_row0_col8, #T_1f384_row0_col9, #T_1f384_row0_col10, #T_1f384_row0_col11, #T_1f384_row0_col12, #T_1f384_row0_col13, #T_1f384_row0_col14, #T_1f384_row0_col15, #T_1f384_row0_col16, #T_1f384_row0_col17, #T_1f384_row0_col18, #T_1f384_row0_col19, #T_1f384_row0_col20, #T_1f384_row0_col21, #T_1f384_row0_col22, #T_1f384_row0_col23, #T_1f384_row0_col24, #T_1f384_row0_col25, #T_1f384_row0_col26, #T_1f384_row0_col27, #T_1f384_row0_col28, #T_1f384_row0_col29, #T_1f384_row0_col30, #T_1f384_row0_col31, #T_1f384_row0_col32, #T_1f384_row0_col33, #T_1f384_row0_col34, #T_1f384_row0_col35, #T_1f384_row0_col36, #T_1f384_row0_col37, #T_1f384_row0_col38, #T_1f384_row0_col39, #T_1f384_row0_col40, #T_1f384_row0_col41, #T_1f384_row0_col42, #T_1f384_row0_col43, #T_1f384_row0_col44, #T_1f384_row0_col45, #T_1f384_row0_col46, #T_1f384_row0_col47, #T_1f384_row0_col48, #T_1f384_row0_col49, #T_1f384_row0_col50, #T_1f384_row0_col51, #T_1f384_row0_col52, #T_1f384_row0_col53 {
#   background-color: lightgreen;
# }
# #T_1f384_row0_col54, #T_1f384_row0_col55, #T_1f384_row0_col56, #T_1f384_row0_col57, #T_1f384_row0_col58, #T_1f384_row0_col59, #T_1f384_row0_col60, #T_1f384_row0_col61, #T_1f384_row0_col62, #T_1f384_row0_col63, #T_1f384_row0_col64, #T_1f384_row0_col65, #T_1f384_row0_col66, #T_1f384_row0_col67, #T_1f384_row0_col68, #T_1f384_row0_col69, #T_1f384_row0_col70, #T_1f384_row0_col71, #T_1f384_row0_col72, #T_1f384_row0_col73, #T_1f384_row0_col74, #T_1f384_row0_col75, #T_1f384_row0_col76, #T_1f384_row0_col77, #T_1f384_row0_col78, #T_1f384_row0_col79, #T_1f384_row0_col80, #T_1f384_row0_col81, #T_1f384_row0_col82, #T_1f384_row0_col83, #T_1f384_row0_col84, #T_1f384_row0_col85, #T_1f384_row0_col86, #T_1f384_row0_col87, #T_1f384_row0_col88, #T_1f384_row0_col89, #T_1f384_row0_col90, #T_1f384_row0_col91, #T_1f384_row0_col92, #T_1f384_row0_col93, #T_1f384_row0_col94, #T_1f384_row0_col95, #T_1f384_row0_col96, #T_1f384_row0_col97, #T_1f384_row0_col98, #T_1f384_row0_col99, #T_1f384_row0_col100, #T_1f384_row0_col101, #T_1f384_row0_col102, #T_1f384_row0_col103, #T_1f384_row0_col104, #T_1f384_row0_col105, #T_1f384_row0_col106, #T_1f384_row0_col107, #T_1f384_row0_col108 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_1f384">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f384_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1f384_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1f384_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_1f384_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_1f384_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_1f384_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_1f384_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_1f384_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_1f384_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_1f384_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_1f384_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_1f384_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_1f384_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_1f384_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_1f384_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_1f384_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_1f384_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_1f384_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_1f384_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_1f384_level0_col19" class="col_heading level0 col19" >19</th>
#       <th id="T_1f384_level0_col20" class="col_heading level0 col20" >20</th>
#       <th id="T_1f384_level0_col21" class="col_heading level0 col21" >21</th>
#       <th id="T_1f384_level0_col22" class="col_heading level0 col22" >22</th>
#       <th id="T_1f384_level0_col23" class="col_heading level0 col23" >23</th>
#       <th id="T_1f384_level0_col24" class="col_heading level0 col24" >24</th>
#       <th id="T_1f384_level0_col25" class="col_heading level0 col25" >25</th>
#       <th id="T_1f384_level0_col26" class="col_heading level0 col26" >26</th>
#       <th id="T_1f384_level0_col27" class="col_heading level0 col27" >27</th>
#       <th id="T_1f384_level0_col28" class="col_heading level0 col28" >28</th>
#       <th id="T_1f384_level0_col29" class="col_heading level0 col29" >29</th>
#       <th id="T_1f384_level0_col30" class="col_heading level0 col30" >30</th>
#       <th id="T_1f384_level0_col31" class="col_heading level0 col31" >31</th>
#       <th id="T_1f384_level0_col32" class="col_heading level0 col32" >32</th>
#       <th id="T_1f384_level0_col33" class="col_heading level0 col33" >33</th>
#       <th id="T_1f384_level0_col34" class="col_heading level0 col34" >34</th>
#       <th id="T_1f384_level0_col35" class="col_heading level0 col35" >35</th>
#       <th id="T_1f384_level0_col36" class="col_heading level0 col36" >36</th>
#       <th id="T_1f384_level0_col37" class="col_heading level0 col37" >37</th>
#       <th id="T_1f384_level0_col38" class="col_heading level0 col38" >38</th>
#       <th id="T_1f384_level0_col39" class="col_heading level0 col39" >39</th>
#       <th id="T_1f384_level0_col40" class="col_heading level0 col40" >40</th>
#       <th id="T_1f384_level0_col41" class="col_heading level0 col41" >41</th>
#       <th id="T_1f384_level0_col42" class="col_heading level0 col42" >42</th>
#       <th id="T_1f384_level0_col43" class="col_heading level0 col43" >43</th>
#       <th id="T_1f384_level0_col44" class="col_heading level0 col44" >44</th>
#       <th id="T_1f384_level0_col45" class="col_heading level0 col45" >45</th>
#       <th id="T_1f384_level0_col46" class="col_heading level0 col46" >46</th>
#       <th id="T_1f384_level0_col47" class="col_heading level0 col47" >47</th>
#       <th id="T_1f384_level0_col48" class="col_heading level0 col48" >48</th>
#       <th id="T_1f384_level0_col49" class="col_heading level0 col49" >49</th>
#       <th id="T_1f384_level0_col50" class="col_heading level0 col50" >50</th>
#       <th id="T_1f384_level0_col51" class="col_heading level0 col51" >51</th>
#       <th id="T_1f384_level0_col52" class="col_heading level0 col52" >52</th>
#       <th id="T_1f384_level0_col53" class="col_heading level0 col53" >53</th>
#       <th id="T_1f384_level0_col54" class="col_heading level0 col54" >54</th>
#       <th id="T_1f384_level0_col55" class="col_heading level0 col55" >55</th>
#       <th id="T_1f384_level0_col56" class="col_heading level0 col56" >56</th>
#       <th id="T_1f384_level0_col57" class="col_heading level0 col57" >57</th>
#       <th id="T_1f384_level0_col58" class="col_heading level0 col58" >58</th>
#       <th id="T_1f384_level0_col59" class="col_heading level0 col59" >59</th>
#       <th id="T_1f384_level0_col60" class="col_heading level0 col60" >60</th>
#       <th id="T_1f384_level0_col61" class="col_heading level0 col61" >61</th>
#       <th id="T_1f384_level0_col62" class="col_heading level0 col62" >62</th>
#       <th id="T_1f384_level0_col63" class="col_heading level0 col63" >63</th>
#       <th id="T_1f384_level0_col64" class="col_heading level0 col64" >64</th>
#       <th id="T_1f384_level0_col65" class="col_heading level0 col65" >65</th>
#       <th id="T_1f384_level0_col66" class="col_heading level0 col66" >66</th>
#       <th id="T_1f384_level0_col67" class="col_heading level0 col67" >67</th>
#       <th id="T_1f384_level0_col68" class="col_heading level0 col68" >68</th>
#       <th id="T_1f384_level0_col69" class="col_heading level0 col69" >69</th>
#       <th id="T_1f384_level0_col70" class="col_heading level0 col70" >70</th>
#       <th id="T_1f
# calculated median = 45.0

# %%
a, b, med = main(a_, b_)
try:
    display(highlight_ol(a))
    display(highlight_ol(b))
except:
    pass
finally:
    display(med)
# Out:
# <style type="text/css">
# #T_2c3ff_row0_col5, #T_2c3ff_row0_col6, #T_2c3ff_row0_col7 {
#   background-color: lightgreen;
# }
# #T_2c3ff_row0_col8, #T_2c3ff_row0_col9, #T_2c3ff_row0_col10 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_2c3ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c3ff_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2c3ff_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2c3ff_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2c3ff_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_2c3ff_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_2c3ff_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_2c3ff_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_2c3ff_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_2c3ff_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_2c3ff_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_2c3ff_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_2c3ff_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_2c3ff_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_2c3ff_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_2c3ff_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_2c3ff_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_2c3ff_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_2c3ff_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_2c3ff_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_2c3ff_level0_col19" class="col_heading level0 col19" >19</th>
#       <th id="T_2c3ff_level0_col20" class="col_heading level0 col20" >20</th>
#       <th id="T_2c3ff_level0_col21" class="col_heading level0 col21" >21</th>
#       <th id="T_2c3ff_level0_col22" class="col_heading level0 col22" >22</th>
#       <th id="T_2c3ff_level0_col23" class="col_heading level0 col23" >23</th>
#       <th id="T_2c3ff_level0_col24" class="col_heading level0 col24" >24</th>
#       <th id="T_2c3ff_level0_col25" class="col_heading level0 col25" >25</th>
#       <th id="T_2c3ff_level0_col26" class="col_heading level0 col26" >26</th>
#       <th id="T_2c3ff_level0_col27" class="col_heading level0 col27" >27</th>
#       <th id="T_2c3ff_level0_col28" class="col_heading level0 col28" >28</th>
#       <th id="T_2c3ff_level0_col29" class="col_heading level0 col29" >29</th>
#       <th id="T_2c3ff_level0_col30" class="col_heading level0 col30" >30</th>
#       <th id="T_2c3ff_level0_col31" class="col_heading level0 col31" >31</th>
#       <th id="T_2c3ff_level0_col32" class="col_heading level0 col32" >32</th>
#       <th id="T_2c3ff_level0_col33" class="col_heading level0 col33" >33</th>
#       <th id="T_2c3ff_level0_col34" class="col_heading level0 col34" >34</th>
#       <th id="T_2c3ff_level0_col35" class="col_heading level0 col35" >35</th>
#       <th id="T_2c3ff_level0_col36" class="col_heading level0 col36" >36</th>
#       <th id="T_2c3ff_level0_col37" class="col_heading level0 col37" >37</th>
#       <th id="T_2c3ff_level0_col38" class="col_heading level0 col38" >38</th>
#       <th id="T_2c3ff_level0_col39" class="col_heading level0 col39" >39</th>
#       <th id="T_2c3ff_level0_col40" class="col_heading level0 col40" >40</th>
#       <th id="T_2c3ff_level0_col41" class="col_heading level0 col41" >41</th>
#       <th id="T_2c3ff_level0_col42" class="col_heading level0 col42" >42</th>
#       <th id="T_2c3ff_level0_col43" class="col_heading level0 col43" >43</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c3ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c3ff_row0_col0" class="data row0 col0" >-inf</td>
#       <td id="T_2c3ff_row0_col1" class="data row0 col1" >40.000000</td>
#       <td id="T_2c3ff_row0_col2" class="data row0 col2" >41.000000</td>
#       <td id="T_2c3ff_row0_col3" class="data row0 col3" >43.000000</td>
#       <td id="T_2c3ff_row0_col4" class="data row0 col4" >44.000000</td>
#       <td id="T_2c3ff_row0_col5" class="data row0 col5" >44.000000</td>
#       <td id="T_2c3ff_row0_col6" class="data row0 col6" >44.000000</td>
#       <td id="T_2c3ff_row0_col7" class="data row0 col7" >45.000000</td>
#       <td id="T_2c3ff_row0_col8" class="data row0 col8" >49.000000</td>
#       <td id="T_2c3ff_row0_col9" class="data row0 col9" >49.000000</td>
#       <td id="T_2c3ff_row0_col10" class="data row0 col10" >50.000000</td>
#       <td id="T_2c3ff_row0_col11" class="data row0 col11" >53.000000</td>
#       <td id="T_2c3ff_row0_col12" class="data row0 col12" >56.000000</td>
#       <td id="T_2c3ff_row0_col13" class="data row0 col13" >58.000000</td>
#       <td id="T_2c3ff_row0_col14" class="data row0 col14" >59.000000</td>
#       <td id="T_2c3ff_row0_col15" class="data row0 col15" >63.000000</td>
#       <td id="T_2c3ff_row0_col16" class="data row0 col16" >63.000000</td>
#       <td id="T_2c3ff_row0_col17" class="data row0 col17" >64.000000</td>
#       <td id="T_2c3ff_row0_col18" class="data row0 col18" >65.000000</td>
#       <td id="T_2c3ff_row0_col19" class="data row0 col19" >72.000000</td>
#       <td id="T_2c3ff_row0_col20" class="data row0 col20" >73.000000</td>
#       <td id="T_2c3ff_row0_col21" class="data row0 col21" >74.000000</td>
#       <td id="T_2c3ff_row0_col22" class="data row0 col22" >74.000000</td>
#       <td id="T_2c3ff_row0_col23" class="data row0 col23" >75.000000</td>
#       <td id="T_2c3ff_row0_col24" class="data row0 col24" >76.000000</td>
#       <td id="T_2c3ff_row0_col25" class="data row0 col25" >76.000000</td>
#       <td id="T_2c3ff_row0_col26" class="data row0 col26" >77.000000</td>
#       <td id="T_2c3ff_row0_col27" class="data row0 col27" >77.000000</td>
#       <td id="T_2c3ff_row0_col28" class="data row0 col28" >79.000000</td>
#       <td id="T_2c3ff_row0_col29" class="data row0 col29" >80.000000</td>
#       <td id="T_2c3ff_row0_col30" class="data row0 col30" >82.000000</td>
#       <td id="T_2c3ff_row0_col31" class="data row0 col31" >82.000000</td>
#       <td id="T_2c3ff_row0_col32" class="data row0 col32" >84.000000</td>
#       <td id="T_2c3ff_row0_col33" class="data row0 col33" >85.000000</td>
#       <td id="T_2c3ff_row0_col34" class="data row0 col34" >86.000000</td>
#       <td id="T_2c3ff_row0_col35" class="data row0 col35" >87.000000</td>
#       <td id="T_2c3ff_row0_col36" class="data row0 col36" >88.000000</td>
#       <td id="T_2c3ff_row0_col37" class="data row0 col37" >89.000000</td>
#       <td id="T_2c3ff_row0_col38" class="data row0 col38" >89.000000</td>
#       <td id="T_2c3ff_row0_col39" class="data row0 col39" >91.000000</td>
#       <td id="T_2c3ff_row0_col40" class="data row0 col40" >93.000000</td>
#       <td id="T_2c3ff_row0_col41" class="data row0 col41" >95.000000</td>
#       <td id="T_2c3ff_row0_col42" class="data row0 col42" >98.000000</td>
#       <td id="T_2c3ff_row0_col43" class="data row0 col43" >inf</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_927f7_row0_col0, #T_927f7_row0_col1, #T_927f7_row0_col2, #T_927f7_row0_col3, #T_927f7_row0_col4, #T_927f7_row0_col5, #T_927f7_row0_col6, #T_927f7_row0_col7, #T_927f7_row0_col8, #T_927f7_row0_col9, #T_927f7_row0_col10, #T_927f7_row0_col11, #T_927f7_row0_col12, #T_927f7_row0_col13, #T_927f7_row0_col14, #T_927f7_row0_col15, #T_927f7_row0_col16, #T_927f7_row0_col17, #T_927f7_row0_col18, #T_927f7_row0_col19, #T_927f7_row0_col20, #T_927f7_row0_col21, #T_927f7_row0_col22, #T_927f7_row0_col23, #T_927f7_row0_col24, #T_927f7_row0_col25, #T_927f7_row0_col26, #T_927f7_row0_col27, #T_927f7_row0_col28, #T_927f7_row0_col29, #T_927f7_row0_col30, #T_927f7_row0_col31, #T_927f7_row0_col32, #T_927f7_row0_col33, #T_927f7_row0_col34, #T_927f7_row0_col35, #T_927f7_row0_col36, #T_927f7_row0_col37, #T_927f7_row0_col38, #T_927f7_row0_col39, #T_927f7_row0_col40, #T_927f7_row0_col41, #T_927f7_row0_col42, #T_927f7_row0_col43, #T_927f7_row0_col44, #T_927f7_row0_col45, #T_927f7_row0_col46 {
#   background-color: lightgreen;
# }
# #T_927f7_row0_col47, #T_927f7_row0_col48, #T_927f7_row0_col49, #T_927f7_row0_col50, #T_927f7_row0_col51, #T_927f7_row0_col52, #T_927f7_row0_col53, #T_927f7_row0_col54, #T_927f7_row0_col55, #T_927f7_row0_col56, #T_927f7_row0_col57, #T_927f7_row0_col58, #T_927f7_row0_col59, #T_927f7_row0_col60, #T_927f7_row0_col61, #T_927f7_row0_col62, #T_927f7_row0_col63, #T_927f7_row0_col64, #T_927f7_row0_col65, #T_927f7_row0_col66 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_927f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_927f7_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_927f7_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_927f7_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_927f7_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_927f7_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_927f7_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_927f7_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_927f7_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_927f7_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_927f7_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_927f7_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_927f7_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_927f7_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_927f7_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_927f7_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_927f7_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_927f7_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_927f7_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_927f7_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_927f7_level0_col19" class="col_heading level0 col19" >19</th>
#       <th id="T_927f7_level0_col20" class="col_heading level0 col20" >20</th>
#       <th id="T_927f7_level0_col21" class="col_heading level0 col21" >21</th>
#       <th id="T_927f7_level0_col22" class="col_heading level0 col22" >22</th>
#       <th id="T_927f7_level0_col23" class="col_heading level0 col23" >23</th>
#       <th id="T_927f7_level0_col24" class="col_heading level0 col24" >24</th>
#       <th id="T_927f7_level0_col25" class="col_heading level0 col25" >25</th>
#       <th id="T_927f7_level0_col26" class="col_heading level0 col26" >26</th>
#       <th id="T_927f7_level0_col27" class="col_heading level0 col27" >27</th>
#       <th id="T_927f7_level0_col28" class="col_heading level0 col28" >28</th>
#       <th id="T_927f7_level0_col29" class="col_heading level0 col29" >29</th>
#       <th id="T_927f7_level0_col30" class="col_heading level0 col30" >30</th>
#       <th id="T_927f7_level0_col31" class="col_heading level0 col31" >31</th>
#       <th id="T_927f7_level0_col32" class="col_heading level0 col32" >32</th>
#       <th id="T_927f7_level0_col33" class="col_heading level0 col33" >33</th>
#       <th id="T_927f7_level0_col34" class="col_heading level0 col34" >34</th>
#       <th id="T_927f7_level0_col35" class="col_heading level0 col35" >35</th>
#       <th id="T_927f7_level0_col36" class="col_heading level0 col36" >36</th>
#       <th id="T_927f7_level0_col37" class="col_heading level0 col37" >37</th>
#       <th id="T_927f7_level0_col38" class="col_heading level0 col38" >38</th>
#       <th id="T_927f7_level0_col39" class="col_heading level0 col39" >39</th>
#       <th id="T_927f7_level0_col40" class="col_heading level0 col40" >40</th>
#       <th id="T_927f7_level0_col41" class="col_heading level0 col41" >41</th>
#       <th id="T_927f7_level0_col42" class="col_heading level0 col42" >42</th>
#       <th id="T_927f7_level0_col43" class="col_heading level0 col43" >43</th>
#       <th id="T_927f7_level0_col44" class="col_heading level0 col44" >44</th>
#       <th id="T_927f7_level0_col45" class="col_heading level0 col45" >45</th>
#       <th id="T_927f7_level0_col46" class="col_heading level0 col46" >46</th>
#       <th id="T_927f7_level0_col47" class="col_heading level0 col47" >47</th>
#       <th id="T_927f7_level0_col48" class="col_heading level0 col48" >48</th>
#       <th id="T_927f7_level0_col49" class="col_heading level0 col49" >49</th>
#       <th id="T_927f7_level0_col50" class="col_heading level0 col50" >50</th>
#       <th id="T_927f7_level0_col51" class="col_heading level0 col51" >51</th>
#       <th id="T_927f7_level0_col52" class="col_heading level0 col52" >52</th>
#       <th id="T_927f7_level0_col53" class="col_heading level0 col53" >53</th>
#       <th id="T_927f7_level0_col54" class="col_heading level0 col54" >54</th>
#       <th id="T_927f7_level0_col55" class="col_heading level0 col55" >55</th>
#       <th id="T_927f7_level0_col56" class="col_heading level0 col56" >56</th>
#       <th id="T_927f7_level0_col57" class="col_heading level0 col57" >57</th>
#       <th id="T_927f7_level0_col58" class="col_heading level0 col58" >58</th>
#       <th id="T_927f7_level0_col59" class="col_heading level0 col59" >59</th>
#       <th id="T_927f7_level0_col60" class="col_heading level0 col60" >60</th>
#       <th id="T_927f7_level0_col61" class="col_heading level0 col61" >61</th>
#       <th id="T_927f7_level0_col62" class="col_heading level0 col62" >62</th>
#       <th id="T_927f7_level0_col63" class="col_heading level0 col63" >63</th>
#       <th id="T_927f7_level0_col64" class="col_heading level0 col64" >64</th>
#       <th id="T_927f7_level0_col65" class="col_heading level0 col65" >65</th>
#       <th id="T_927f7_level0_col66" class="col_heading level0 col66" >66</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_927f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_927f7_row0_col0" class="data row0 col0" >-inf</td>
#       <td id="T_927f7_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_927f7_row0_col2" class="data row0 col2" >2.000000</td>
#       <td id="T_927f7_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_927f7_row0_col4" class="data row0 col4" >3.000000</td>
#       <td id="T_927f7_row0_col5" class="data row0 col5" >3.000000</td>
#       <td id="T_927f7_row0_col6" class="data row0 col6" >3.000000</td>
#       <td id="T_927f7_row0_col7" class="data row0 col7" >7.000000</td>
#       <td id="T_927f7_row0_col8" class="data row0 col8" >8.000000</td>
#       <td id="T_927f7_row0_col9" class="data row0 col9" >9.000000</td>
#       <td id="T_927f7_row0_col10" class="data row0 col10" >9.000000</td>
#       <td id="T_927f7_row0_col11" class="data row0 col11" >10.000000</td>
#       <td id="T_927f7_row0_col12" class="data row0 col12" >12.000000</td>
#       <td id="T_927f7_row0_col13" class="data row0 col13" >13.000000</td>
#       <td id="T_927f7_row0_col14" class="data row0 col14" >13.000000</td>
#       <td id="T_927f7_row0_col1
# 45

# %%
print(f"calculated med == med: {med_calc == med}")
# Out:
# calculated med == med: True
